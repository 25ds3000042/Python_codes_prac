# %% [markdown]
# <a href="https://colab.research.google.com/github/25ds3000042/Python_codes_prac/blob/main/Functions/all_functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# multiple parameters

# %%
def add(a, b):
    print(a + b)

# %%
add(4,6)
# Out:
# 10

# %% [markdown]
# arguments according to their position

# %%
def student(name, age):
    print(name)
    print(age)

# %%
student("Bob", 32)
# Out:
# Bob
# 32
